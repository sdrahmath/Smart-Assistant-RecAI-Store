# %%
product_data = {
    "apple": {
        "Product ID": "APL001",
        "Category": "Fruits",
        "Price": 1.0,
        "Unit of Measure": "Each",
        "Description": "Fresh and juicy apples",
        "Image URL": "https://example.com/apple.jpg",
        "Stock Availability": 100,
        "Discount": 0.0,
        "Origin": "USA",
    },
    "banana": {
        "Product ID": "BAN001",
        "Category": "Fruits",
        "Price": 0.5,
        "Unit of Measure": "Each",
        "Description": "Ripe and yellow bananas",
        "Image URL": "https://example.com/banana.jpg",
        "Stock Availability": 150,
        "Discount": 0.0,
        "Origin": "Mexico",
    },
    "beetroot": {
        "Product ID": "BTR001",
        "Category": "Vegetables",
        "Price": 1.2,
        "Unit of Measure": "Each",
        "Description": "Fresh beetroot with tops",
        "Image URL": "https://example.com/beetroot.jpg",
        "Stock Availability": 80,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "bell pepper": {
        "Product ID": "BPP001",
        "Category": "Vegetables",
        "Price": 1.5,
        "Unit of Measure": "Each",
        "Description": "Assorted bell peppers (red, yellow, green)",
        "Image URL": "https://example.com/bellpepper.jpg",
        "Stock Availability": 70,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "cabbage": {
        "Product ID": "CAB001",
        "Category": "Vegetables",
        "Price": 0.8,
        "Unit of Measure": "Each",
        "Description": "Fresh green cabbage",
        "Image URL": "https://example.com/cabbage.jpg",
        "Stock Availability": 90,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "capsicum": {
        "Product ID": "CAP001",
        "Category": "Vegetables",
        "Price": 1.2,
        "Unit of Measure": "Each",
        "Description": "Green bell pepper",
        "Image URL": "https://example.com/capsicum.jpg",
        "Stock Availability": 50,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "carrot": {
        "Product ID": "CAR001",
        "Category": "Vegetables",
        "Price": 0.6,
        "Unit of Measure": "Each",
        "Description": "Fresh carrots",
        "Image URL": "https://example.com/carrot.jpg",
        "Stock Availability": 120,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "cauliflower": {
        "Product ID": "CAF001",
        "Category": "Vegetables",
        "Price": 1.2,
        "Unit of Measure": "Each",
        "Description": "Fresh cauliflower",
        "Image URL": "https://example.com/cauliflower.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "chilli pepper": {
        "Product ID": "CHP001",
        "Category": "Vegetables",
        "Price": 0.8,
        "Unit of Measure": "Each",
        "Description": "Fresh red chilli pepper",
        "Image URL": "https://example.com/chillipepper.jpg",
        "Stock Availability": 40,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "corn": {
        "Product ID": "CRN001",
        "Category": "Vegetables",
        "Price": 0.9,
        "Unit of Measure": "Each",
        "Description": "Sweet corn on the cob",
        "Image URL": "https://example.com/corn.jpg",
        "Stock Availability": 70,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "cucumber": {
        "Product ID": "CUC001",
        "Category": "Vegetables",
        "Price": 0.7,
        "Unit of Measure": "Each",
        "Description": "Fresh green cucumber",
        "Image URL": "https://example.com/cucumber.jpg",
        "Stock Availability": 90,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "eggplant": {
        "Product ID": "EGP001",
        "Category": "Vegetables",
        "Price": 1.0,
        "Unit of Measure": "Each",
        "Description": "Purple eggplant",
        "Image URL": "https://example.com/eggplant.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "garlic": {
        "Product ID": "GRL001",
        "Category": "Vegetables",
        "Price": 0.3,
        "Unit of Measure": "Each",
        "Description": "Fresh garlic bulbs",
        "Image URL": "https://example.com/garlic.jpg",
        "Stock Availability": 100,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "ginger": {
        "Product ID": "GIN001",
        "Category": "Vegetables",
        "Price": 0.5,
        "Unit of Measure": "Each",
        "Description": "Fresh ginger root",
        "Image URL": "https://example.com/ginger.jpg",
        "Stock Availability": 80,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "grapes": {
        "Product ID": "GRP001",
        "Category": "Fruits",
        "Price": 2.0,
        "Unit of Measure": "Each",
        "Description": "Red and green grapes",
        "Image URL": "https://example.com/grapes.jpg",
        "Stock Availability": 40,
        "Discount": 0.0,
        "Origin": "USA",
    },
    "jalepeno": {
        "Product ID": "JAL001",
        "Category": "Vegetables",
        "Price": 0.7,
        "Unit of Measure": "Each",
        "Description": "Fresh jalapeño peppers",
        "Image URL": "https://example.com/jalapeno.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "Mexico",
    },
    "kiwi": {
        "Product ID": "KIW001",
        "Category": "Fruits",
        "Price": 1.5,
        "Unit of Measure": "Each",
        "Description": "Ripe and sweet kiwi",
        "Image URL": "https://example.com/kiwi.jpg",
        "Stock Availability": 50,
        "Discount": 0.0,
        "Origin": "New Zealand",
    },
    "lemon": {
        "Product ID": "LEM001",
        "Category": "Fruits",
        "Price": 0.6,
        "Unit of Measure": "Each",
        "Description": "Fresh and tangy lemons",
        "Image URL": "https://example.com/lemon.jpg",
        "Stock Availability": 70,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "lettuce": {
        "Product ID": "LET001",
        "Category": "Vegetables",
        "Price": 0.9,
        "Unit of Measure": "Each",
        "Description": "Crisp and green lettuce",
        "Image URL": "https://example.com/lettuce.jpg",
        "Stock Availability": 80,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "mango": {
        "Product ID": "MAN001",
        "Category": "Fruits",
        "Price": 1.2,
        "Unit of Measure": "Each",
        "Description": "Ripe and sweet mangoes",
        "Image URL": "https://example.com/mango.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "India",
    },
    "onion": {
        "Product ID": "ONI001",
        "Category": "Vegetables",
        "Price": 0.5,
        "Unit of Measure": "Each",
        "Description": "Fresh onions",
        "Image URL": "https://example.com/onion.jpg",
        "Stock Availability": 90,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "orange": {
        "Product ID": "ORA001",
        "Category": "Fruits",
        "Price": 0.8,
        "Unit of Measure": "Each",
        "Description": "Sweet and juicy oranges",
        "Image URL": "https://example.com/orange.jpg",
        "Stock Availability": 80,
        "Discount": 0.0,
        "Origin": "USA",
    },
    "paprika": {
        "Product ID": "PAP001",
        "Category": "Vegetables",
        "Price": 1.0,
        "Unit of Measure": "Each",
        "Description": "Red paprika peppers",
        "Image URL": "https://example.com/paprika.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "pear": {
        "Product ID": "PEA001",
        "Category": "Fruits",
        "Price": 1.0,
        "Unit of Measure": "Each",
        "Description": "Juicy pears",
        "Image URL": "https://example.com/pear.jpg",
        "Stock Availability": 100,
        "Discount": 0.0,
        "Origin": "USA",
    },
    "peas": {
        "Product ID": "PEA001",
        "Category": "Vegetables",
        "Price": 0.8,
        "Unit of Measure": "Each",
        "Description": "Fresh green peas",
        "Image URL": "https://example.com/peas.jpg",
        "Stock Availability": 70,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "pineapple": {
        "Product ID": "PIN001",
        "Category": "Fruits",
        "Price": 1.5,
        "Unit of Measure": "Each",
        "Description": "Ripe and delicious pineapples",
        "Image URL": "https://example.com/pineapple.jpg",
        "Stock Availability": 50,
        "Discount": 0.0,
        "Origin": "Hawaii",
    },
    "pomegranate": {
        "Product ID": "POM001",
        "Category": "Fruits",
        "Price": 1.3,
        "Unit of Measure": "Each",
        "Description": "Sweet and nutritious pomegranates",
        "Image URL": "https://example.com/pomegranate.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "potato": {
        "Product ID": "POT001",
        "Category": "Vegetables",
        "Price": 0.4,
        "Unit of Measure": "Each",
        "Description": "Fresh and versatile potatoes",
        "Image URL": "https://example.com/potato.jpg",
        "Stock Availability": 120,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "raddish": {
        "Product ID": "RAD001",
        "Category": "Vegetables",
        "Price": 0.7,
        "Unit of Measure": "Each",
        "Description": "Crunchy red radishes",
        "Image URL": "https://example.com/radish.jpg",
        "Stock Availability": 80,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "soy beans": {
        "Product ID": "SOY001",
        "Category": "Vegetables",
        "Price": 1.2,
        "Unit of Measure": "Each",
        "Description": "Fresh soybean pods",
        "Image URL": "https://example.com/soybeans.jpg",
        "Stock Availability": 70,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "spinach": {
        "Product ID": "SPN001",
        "Category": "Vegetables",
        "Price": 0.9,
        "Unit of Measure": "Each",
        "Description": "Nutrient-rich spinach leaves",
        "Image URL": "https://example.com/spinach.jpg",
        "Stock Availability": 90,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "sweetcorn": {
        "Product ID": "SWC001",
        "Category": "Vegetables",
        "Price": 0.9,
        "Unit of Measure": "Each",
        "Description": "Fresh sweetcorn",
        "Image URL": "https://example.com/sweetcorn.jpg",
        "Stock Availability": 60,
        "Discount": 0.0,
        "Origin": "Local",
    },
    "sweetpotato": {
        "Product ID": "SPT001",
        "Category": "Vegetables",
    "Price": 1.2,
    "Unit of Measure": "Each",
    "Description": "Fresh sweet potatoes",
    "Image URL": "https://example.com/sweetpotato.jpg",
    "Stock Availability": 90,
    "Discount": 0.0,
    "Origin": "Local",
},
"tomato":{
    "Product ID": "TMT001",
    "Category": "Vegetables",
    "Price": 1.0,
    "Unit of Measure": "Each",
    "Description": "Ripe and red tomatoes",
    "Image URL": "https://example.com/tomato.jpg",
    "Stock Availability": 120,
    "Discount": 0.0,
    "Origin": "Local",
},
"turnip":{
    "Product ID": "TUR001",
    "Category": "Vegetables",
    "Price": 0.8,
    "Unit of Measure": "Each",
    "Description": "Fresh turnips with greens",
    "Image URL": "https://example.com/turnip.jpg",
    "Stock Availability": 60,
    "Discount": 0.0,
    "Origin": "Local",
},
"watermelon":{
    "Product ID": "WM001",
    "Category": "Fruits",
    "Price": 2.5,
    "Unit of Measure": "Each",
    "Description": "Large and juicy watermelons",
    "Image URL": "https://example.com/watermelon.jpg",
    "Stock Availability": 40,
    "Discount": 0.0,
    "Origin": "Local",
}}

# %%
import pandas as pd

# Your dictionary of product data


# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(product_data, orient='index')

# If you want to reset the index and have a numeric index
# df.reset_index(inplace=True)
# df.rename(columns={'index': 'Product'}, inplace=True)

# Display the DataFrame
print(df)
# Out:
#               Product ID    Category  Price Unit of Measure  \
# apple             APL001      Fruits    1.0            Each
# banana            BAN001      Fruits    0.5            Each
# beetroot          BTR001  Vegetables    1.2            Each
# bell pepper       BPP001  Vegetables    1.5            Each
# cabbage           CAB001  Vegetables    0.8            Each
# capsicum          CAP001  Vegetables    1.2            Each
# carrot            CAR001  Vegetables    0.6            Each
# cauliflower       CAF001  Vegetables    1.2            Each
# chilli pepper     CHP001  Vegetables    0.8            Each
# corn              CRN001  Vegetables    0.9            Each
# cucumber          CUC001  Vegetables    0.7            Each
# eggplant          EGP001  Vegetables    1.0            Each
# garlic            GRL001  Vegetables    0.3            Each
# ginger            GIN001  Vegetables    0.5            Each
# grapes            GRP001      Fruits    2.0            Each
# ...

# %%
df
# Out:
#               Product ID    Category  Price Unit of Measure  \
# apple             APL001      Fruits    1.0            Each
# banana            BAN001      Fruits    0.5            Each
# beetroot          BTR001  Vegetables    1.2            Each
# bell pepper       BPP001  Vegetables    1.5            Each
# cabbage           CAB001  Vegetables    0.8            Each
# capsicum          CAP001  Vegetables    1.2            Each
# carrot            CAR001  Vegetables    0.6            Each
# cauliflower       CAF001  Vegetables    1.2            Each
# chilli pepper     CHP001  Vegetables    0.8            Each
# corn              CRN001  Vegetables    0.9            Each
# cucumber          CUC001  Vegetables    0.7            Each
# eggplant          EGP001  Vegetables    1.0            Each
# garlic            GRL001  Vegetables    0.3            Each
# ginger            GIN001  Vegetables    0.5            Each
# grapes            GRP001      Fruits    2.0            Each
# ...

# %%
df.reset_index(inplace=True)
df.rename(columns={'index': 'name'}, inplace=True)

# %%
df
# Out:
#              name Product ID    Category  Price Unit of Measure  \
# 0           apple     APL001      Fruits    1.0            Each
# 1          banana     BAN001      Fruits    0.5            Each
# 2        beetroot     BTR001  Vegetables    1.2            Each
# 3     bell pepper     BPP001  Vegetables    1.5            Each
# 4         cabbage     CAB001  Vegetables    0.8            Each
# 5        capsicum     CAP001  Vegetables    1.2            Each
# 6          carrot     CAR001  Vegetables    0.6            Each
# 7     cauliflower     CAF001  Vegetables    1.2            Each
# 8   chilli pepper     CHP001  Vegetables    0.8            Each
# 9            corn     CRN001  Vegetables    0.9            Each
# 10       cucumber     CUC001  Vegetables    0.7            Each
# 11       eggplant     EGP001  Vegetables    1.0            Each
# 12         garlic     GRL001  Vegetables    0.3            Each
# 13         ginger     GIN001  Vegetables    0.5            Each
# ...

# %%
df.to_csv('Fruitsandveg.csv')
